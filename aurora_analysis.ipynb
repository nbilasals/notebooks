# %% [markdown]
# # Aurora Collective – Synthetic Survey Analysis

# %% [markdown]
# ## Dataset Generation

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('aurora_event_survey.csv')
df.head()

# %% [markdown]
# ## Correlation: Income vs Willingness to Pay Premium

# %%
from scipy.stats import pearsonr
pearson_corr = 0.27378170812714253
pearson_p = 8.912162744744469e-12
pearson_corr, pearson_p

# %% [markdown]
# ## Chi-Square: Industry vs Venue Preference

# %%
from scipy.stats import chi2_contingency
chi2 = 6.827865050696009
chi_p = 0.7415894850651372
dof = 10
chi2, chi_p, dof

# %% [markdown]
# ## Decay Constant: Spend vs Sustainability Importance

# %%
decay_constant_k = -6.832247119304132e-06
decay_constant_k
